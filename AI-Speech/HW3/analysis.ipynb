# %%
import pandas as pd

DIM = 10

weights = [list() for _ in range(DIM)]
losses = list()

with open('output.dat', 'r') as f:
    for _ in range(1000):
        line = f.readline()
        tokens = line.split()

        for i in range(DIM):
            weights[i].append(tokens[i])
            
        losses.append(tokens[-1])

# %%
dic = {f'weight{idx + 1}' : weight for idx, weight in enumerate(weights)}
dic['loss'] = losses

df = pd.DataFrame(dic)
df = df.astype(float)

# %%
df['loss'].plot(kind='line')

# %%
df['weight1'].plot(kind='line')

# %%
df['weight2'].plot(kind='line')

# %%
df['weight3'].plot(kind='line')

# %%
df['weight4'].plot(kind='line')

# %%
df['weight5'].plot(kind='line')

# %%
df['weight6'].plot(kind='line')

# %%
df['weight7'].plot(kind='line')

# %%
df['weight8'].plot(kind='line')

# %%
df['weight9'].plot(kind='line')

# %%
df['weight10'].plot(kind='line')
