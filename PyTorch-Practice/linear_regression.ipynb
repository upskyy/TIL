# %%
from torch import nn
import torch
from torch import tensor

x_data = tensor([[1.0],[2.0],[3.0]])
y_data = tensor([[2.0],[4.0],[6.0]])

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear = torch.nn.Linear(1,1) # One in and One out
    
    def forward(self, x):
        y_pred = self.linear(x)
        return y_pred

# %%
# optimizer SGD
model = Model()

criterion = torch.nn.MSELoss(reduction = 'sum')
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
# Training loop
for epoch in range(500):
    # 1) Forward pass
    y_pred = model(x_data)
    # 2) Compute and print loss
    loss = criterion(y_pred, y_data)
    print(f"Epoch : {epoch} | Loss : {loss.item()} ")
    
    # Zero gradients, perform a backward pass, and update the weights.
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    
    
# After training
hour_var = tensor([[4.0]])
y_pred = model(hour_var)
print("Prediction (after training)", 4, model(hour_var).data[0][0].item())
# Out:
# Epoch : 0 | Loss : 18.564119338989258
# Epoch : 1 | Loss : 8.592277526855469
# Epoch : 2 | Loss : 4.148380279541016
# Epoch : 3 | Loss : 2.1654374599456787
# Epoch : 4 | Loss : 1.2781075239181519
# Epoch : 5 | Loss : 0.8785790801048279
# Epoch : 6 | Loss : 0.6962715983390808
# Epoch : 7 | Loss : 0.6107269525527954
# Epoch : 8 | Loss : 0.5683227777481079
# Epoch : 9 | Loss : 0.5451852083206177
# Epoch : 10 | Loss : 0.5306862592697144
# Epoch : 11 | Loss : 0.5200921297073364
# Epoch : 12 | Loss : 0.5112977027893066
# Epoch : 13 | Loss : 0.5033610463142395
# Epoch : 14 | Loss : 0.4958652853965759
# Epoch : 15 | Loss : 0.4886225461959839
# Epoch : 16 | Loss : 0.4815483093261719
# Epoch : 17 | Loss : 0.4746047258377075
# Epoch : 18 | Loss : 0.4677736759185791
# Epoch : 19 | Loss : 0.4610465168952942
# Epoch : 20 | Loss : 0.45441827178001404
# Epoch : 21 | Loss : 0.44788646697998047
# Epoch : 22 | Loss : 0.44144949316978455
# Epoch : 23 | Loss : 0.43510517477989197
# Epoch : 24 | Loss : 0.4288518726825714
# Epoch : 25 | Loss : 0.42268845438957214
# Epoch : 26 | Loss : 0.41661369800567627
# Epoch : 27 | Loss : 0.4106265604496002
# Epoch : 28 | Loss : 0.4047248065471649
# Epoch : 29 | Loss : 0.39890819787979126
# Epoch : 30 | Loss : 0.3931754231452942
# Epoch : 31 | Loss : 0.3875248432159424
# Epoch : 32 | Loss : 0.381955623626709
# Epoch : 33 | Loss : 0.3764660954475403
# Epoch : 34 | Loss : 0.371055543422699
# Epoch : 35 | Loss : 0.36572298407554626
# Epoch : 36 | Loss : 0.3604668974876404
# Epoch : 37 | Loss : 0.3552868366241455
# Epoch : 38 | Loss : 0.350180447101593
# Epoch : 39 | Loss : 0.34514790773391724
# Epoch : 40 | Loss : 0.340187668800354
# Epoch : 41 | Loss : 0.3352985978126526
# Epoch : 42 | Loss : 0.33047956228256226
# Epoch : 43 | Loss : 0.32573050260543823
# Epoch : 44 | Loss : 0.32104918360710144
# Epoch : 45 | Loss : 0.3164350092411041
# Epoch : 46 | Loss : 0.31188729405403137
# Epoch : 47 | Loss : 0.30740493535995483
# Epoch : 48 | Loss : 0.30298709869384766
# Epoch : 49 | Loss : 0.29863303899765015
# Epoch : 50 | Loss : 0.29434093832969666
# Epoch : 51 | Loss : 0.2901107668876648
# Epoch : 52 | Loss : 0.2859412431716919
# Epoch : 53 | Loss : 0.2818320393562317
# Epoch : 54 | Loss : 0.27778196334838867
# Epoch : 55 | Loss : 0.2737894654273987
# Epoch : 56 | Loss : 0.269854873418808
# Epoch : 57 | Loss : 0.2659767270088196
# Epoch : 58 | Loss : 0.26215386390686035
# Epoch : 59 | Loss : 0.25838643312454224
# Epoch : 60 | Loss : 0.254673033952713
# Epoch : 61 | Loss : 0.2510130703449249
# Epoch : 62 | Loss : 0.2474054992198944
# Epoch : 63 | Loss : 0.24384981393814087
# Epoch : 64 | Loss : 0.24034518003463745
# Epoch : 65 | Loss : 0.23689135909080505
# Epoch : 66 | Loss : 0.2334866225719452
# Epoch : 67 | Loss : 0.230131134390831
# Epoch : 68 | Loss : 0.22682377696037292
# Epoch : 69 | Loss : 0.22356393933296204
# Epoch : 70 | Loss : 0.22035115957260132
# Epoch : 71 | Loss : 0.21718430519104004
# Epoch : 72 | Loss : 0.2140629142522812
# Epoch : 73 | Loss : 0.2109866440296173
# Epoch : 74 | Loss : 0.20795443654060364
# Epoch : 75 | Loss : 0.20496559143066406
# Epoch : 76 | Loss : 0.20201992988586426
# Epoch : 77 | Loss : 0.19911661744117737
# Epoch : 78 | Loss : 0.1962551474571228
# Epoch : 79 | Loss : 0.19343432784080505
# Epoch : 80 | Loss : 0.19065454602241516
# Epoch : 81 | Loss : 0.18791446089744568
# Epoch : 82 | Loss : 0.18521390855312347
# Epoch : 83 | Loss : 0.18255193531513214
# Epoch : 84 | Loss : 0.1799285113811493
# Epoch : 85 | Loss : 0.17734281718730927
# Epoch : 86 | Loss : 0.17479383945465088
# Epoch : 87 | Loss : 0.17228193581104279
# Epoch : 88 | Loss : 0.169806107878685
# Epoch : 89 | Loss : 0.16736575961112976
# Epoch : 90 | Loss : 0.1649603545665741
# Epoch : 91 | Loss : 0.16258952021598816
# Epoch : 92 | Loss : 0.16025276482105255
# Epoch : 93 | Loss : 0.15794984996318817
# Epoch : 94 | Loss : 0.1556798219680786
# Epoch : 95 | Loss : 0.15344247221946716
# Epoch : 96 | Loss : 0.1512373834848404
# Epoch : 97 | Loss : 0.14906378090381622
# Epoch : 98 | Loss : 0.1469215750694275
# Epoch : 99 | Loss : 0.14480996131896973
# Epoch : 100 | Loss : 0.14272883534431458
# Epoch : 101 | Loss : 0.14067746698856354
# Epoch : 102 | Loss : 0.1386558711528778
# Epoch : 103 | Loss : 0.13666315376758575
# Epoch : 104 | Loss : 0.13469909131526947
# Epoch : 105 | Loss : 0.1327633410692215
# Epoch : 106 | Loss : 0.13085521757602692
# Epoch : 107 | Loss : 0.1289745271205902
# Epoch : 108 | Loss : 0.12712107598781586
# Epoch : 109 | Loss : 0.12529410421848297
# Epoch : 110 | Loss : 0.12349347025156021
# Epoch : 111 | Loss : 0.12171860039234161
# Epoch : 112 | Loss : 0.11996927857398987
# Epoch : 113 | Loss : 0.11824527382850647
# Epoch : 114 | Loss : 0.11654572933912277
# Epoch : 115 | Loss : 0.11487089097499847
# Epoch : 116 | Loss : 0.11321988701820374
# Epoch : 117 | Loss : 0.11159288138151169
# Epoch : 118 | Loss : 0.10998900234699249
# Epoch : 119 | Loss : 0.10840828716754913
# Epoch : 120 | Loss : 0.10685029625892639
# Epoch : 121 | Loss : 0.10531483590602875
# Epoch : 122 | Loss : 0.10380129516124725
# Epoch : 123 | Loss : 0.10230936110019684
# Epoch : 124 | Loss : 0.1008390486240387
# Epoch : 125 | Loss : 0.09938974678516388
# Epoch : 126 | Loss : 0.09796154499053955
# Epoch : 127 | Loss : 0.09655368328094482
# Epoch : 128 | Loss : 0.09516605734825134
# Epoch : 129 | Loss : 0.09379845857620239
# Epoch : 130 | Loss : 0.09245038777589798
# Epoch : 131 | Loss : 0.09112168103456497
# Epoch : 132 | Loss : 0.08981216698884964
# Epoch : 133 | Loss : 0.08852137625217438
# Epoch : 134 | Loss : 0.08724923431873322
# Epoch : 135 | Loss : 0.0859953984618187
# Epoch : 136 | Loss : 0.08475938439369202
# Epoch : 137 | Loss : 0.08354117721319199
# Epoch : 138 | Loss : 0.08234065771102905
# Epoch : 139 | Loss : 0.08115725219249725
# Epoch : 140 | Loss : 0.07999085634946823
# Epoch : 141 | Loss : 0.07884138822555542
# Epoch : 142 | Loss : 0.07770830392837524
# Epoch : 143 | Loss : 0.07659147679805756
# Epoch : 144 | Loss : 0.07549060881137848
# Epoch : 145 | Loss : 0.07440578937530518
# Epoch : 146 | Loss : 0.07333646714687347
# Epoch : 147 | Loss : 0.07228244841098785
# Epoch : 148 | Loss : 0.0712435394525528
# Epoch : 149 | Loss : 0.07021967321634293
# Epoch : 150 | Loss : 0.06921058893203735
# Epoch : 151 | Loss : 0.06821593642234802
# Epoch : 152 | Loss : 0.06723569333553314
# Epoch : 153 | Loss : 0.06626928597688675
# Epoch : 154 | Loss : 0.06531693041324615
# Epoch : 155 | Loss : 0.06437822431325912
# Epoch : 156 | Loss : 0.06345291435718536
# Epoch : 157 | Loss : 0.06254106760025024
# Epoch : 158 | Loss : 0.061642229557037354
# Epoch : 159 | Loss : 0.060756318271160126
# Epoch : 160 | Loss : 0.05988319590687752
# Epoch : 161 | Loss : 0.05902263522148132
# Epoch : 162 | Loss : 0.05817437171936035
# Epoch : 163 | Loss : 0.057338178157806396
# Epoch : 164 | Loss : 0.05651411414146423
# Epoch : 165 | Loss : 0.055702004581689835
# Epoch : 166 | Loss : 0.05490155145525932
# Epoch : 167 | Loss : 0.054112520068883896
# Epoch : 168 | Loss : 0.05333476886153221
# Epoch : 169 | Loss : 0.05256830155849457
# Epoch : 170 | Loss : 0.051812902092933655
# Epoch : 171 | Loss : 0.05106811970472336
# Epoch : 172 | Loss : 0.050334230065345764
# Epoch : 173 | Loss : 0.04961080849170685
# Epoch : 174 | Loss : 0.048897817730903625
# Epoch : 175 | Loss : 0.048195160925388336
# Epoch : 176 | Loss : 0.047502487897872925
# Epoch : 177 | Loss : 0.04681987687945366
# Epoch : 178 | Loss : 0.04614691436290741
# Epoch : 179 | Loss : 0.045483700931072235
# Epoch : 180 | Loss : 0.04483003169298172
# Epoch : 181 | Loss : 0.044185806065797806
# Epoch : 182 | Loss : 0.04355067014694214
# Epoch : 183 | Loss : 0.04292484000325203
# Epoch : 184 | Loss : 0.04230800271034241
# Epoch : 185 | Loss : 0.04169989004731178
# Epoch : 186 | Loss : 0.04110056906938553
# Epoch : 187 | Loss : 0.04050987586379051
# Epoch : 188 | Loss : 0.0399276539683342
# Epoch : 189 | Loss : 0.03935392200946808
# Epoch : 190 | Loss : 0.03878837823867798
# Epoch : 191 | Loss : 0.038230814039707184
# Epoch : 192 | Loss : 0.0376814603805542
# Epoch : 193 | Loss : 0.0371398851275444
# Epoch : 194 | Loss : 0.0366060808300972
# Epoch : 195 | Loss : 0.036080021411180496
# Epoch : 196 | Loss : 0.0355614572763443
# Epoch : 197 | Loss : 0.035050489008426666
# Epoch : 198 | Loss : 0.03454665467143059
# Epoch : 199 | Loss : 0.03405025601387024
# Epoch : 200 | Loss : 0.033560846000909805
# Epoch : 201 | Loss : 0.03307857736945152
# Epoch : 202 | Loss : 0.03260314464569092
# Epoch : 203 | Loss : 0.03213459253311157
# Epoch : 204 | Loss : 0.03167266398668289
# Epoch : 205 | Loss : 0.03121751919388771
# Epoch : 206 | Loss : 0.03076896257698536
# Epoch : 207 | Loss : 0.030326759442687035
# Epoch : 208 | Loss : 0.029890846461057663
# Epoch : 209 | Loss : 0.029461300000548363
# Epoch : 210 | Loss : 0.02903786301612854
# Epoch : 211 | Loss : 0.028620535507798195
# Epoch : 212 | Loss : 0.028209201991558075
# Epoch : 213 | Loss : 0.027803845703601837
# Epoch : 214 | Loss : 0.02740427851676941
# Epoch : 215 | Loss : 0.02701045386493206
# Epoch : 216 | Loss : 0.026622258126735687
# Epoch : 217 | Loss : 0.02623968943953514
# Epoch : 218 | Loss : 0.025862568989396095
# Epoch : 219 | Loss : 0.02549087442457676
# Epoch : 220 | Loss : 0.02512446790933609
# Epoch : 221 | Loss : 0.024763494729995728
# Epoch : 222 | Loss : 0.02440759725868702
# Epoch : 223 | Loss : 0.02405671961605549
# Epoch : 224 | Loss : 0.023711031302809715
# Epoch : 225 | Loss : 0.023370234295725822
# Epoch : 226 | Loss : 0.023034419864416122
# Epoch : 227 | Loss : 0.02270333282649517
# Epoch : 228 | Loss : 0.022377092391252518
# Epoch : 229 | Loss : 0.022055480629205704
# Epoch : 230 | Loss : 0.021738514304161072
# Epoch : 231 | Loss : 0.02142604999244213
# Epoch : 232 | Loss : 0.021118145436048508
# Epoch : 233 | Loss : 0.02081470936536789
# Epoch : 234 | Loss : 0.02051551640033722
# Epoch : 235 | Loss : 0.020220739766955376
# Epoch : 236 | Loss : 0.019930098205804825
# Epoch : 237 | Loss : 0.01964370533823967
# Epoch : 238 | Loss : 0.01936129294335842
# Epoch : 239 | Loss : 0.019083060324192047
# Epoch : 240 | Loss : 0.018808845430612564
# Epoch : 241 | Loss : 0.01853855326771736
# Epoch : 242 | Loss : 0.018272120505571365
# Epoch : 243 | Loss : 0.0180094875395298
# Epoch : 244 | Loss : 0.017750656232237816
# Epoch : 245 | Loss : 0.0174955353140831
# Epoch : 246 | Loss : 0.017244085669517517
# Epoch : 247 | Loss : 0.016996266320347786
# Epoch : 248 | Loss : 0.01675199531018734
# Epoch : 249 | Loss : 0.01651127077639103
# Epoch : 250 | Loss : 0.016273949295282364
# Epoch : 251 | Loss : 0.016040120273828506
# Epoch : 252 | Loss : 0.01580955646932125
# Epoch : 253 | Loss : 0.015582396648824215
# Epoch : 254 | Loss : 0.015358492732048035
# Epoch : 255 | Loss : 0.01513766311109066
# Epoch : 256 | Loss : 0.014920121990144253
# Epoch : 257 | Loss : 0.014705699868500233
# Epoch : 258 | Loss : 0.014494368806481361
# Epoch : 259 | Loss : 0.014286104589700699
# Epoch : 260 | Loss : 0.014080775901675224
# Epoch : 261 | Loss : 0.013878419063985348
# Epoch : 262 | Loss : 0.013678954914212227
# Epoch : 263 | Loss : 0.013482324779033661
# Epoch : 264 | Loss : 0.013288586400449276
# Epoch : 265 | Loss : 0.01309764850884676
# Epoch : 266 | Loss : 0.01290937326848507
# Epoch : 267 | Loss : 0.012723877094686031
# Epoch : 268 | Loss : 0.012540999799966812
# Epoch : 269 | Loss : 0.012360798195004463
# Epoch : 270 | Loss : 0.012183074839413166
# Epoch : 271 | Loss : 0.012008053250610828
# Epoch : 272 | Loss : 0.011835454031825066
# Epoch : 273 | Loss : 0.011665323749184608
# Epoch : 274 | Loss : 0.01149765308946371
# Epoch : 275 | Loss : 0.011332440190017223
# Epoch : 276 | Loss : 0.011169645003974438
# Epoch : 277 | Loss : 0.011009102687239647
# Epoch : 278 | Loss : 0.010850897058844566
# Epoch : 279 | Loss : 0.010694900527596474
# Epoch : 280 | Loss : 0.010541192255914211
# Epoch : 281 | Loss : 0.010389716364443302
# Epoch : 282 | Loss : 0.010240418836474419
# Epoch : 283 | Loss : 0.010093225166201591
# Epoch : 284 | Loss : 0.00994816329330206
# Epoch : 285 | Loss : 0.009805153124034405
# Epoch : 286 | Loss : 0.00966427568346262
# Epoch : 287 | Loss : 0.009525410830974579
# Epoch : 288 | Loss : 0.009388542734086514
# Epoch : 289 | Loss : 0.009253554977476597
# Epoch : 290 | Loss : 0.0091205770149827
# Epoch : 291 | Loss : 0.008989520370960236
# Epoch : 292 | Loss : 0.008860343135893345
# Epoch : 293 | Loss : 0.008732985705137253
# Epoch : 294 | Loss : 0.00860744621604681
# Epoch : 295 | Loss : 0.008483735844492912
# Epoch : 296 | Loss : 0.00836184248328209
# Epoch : 297 | Loss : 0.00824169535189867
# Epoch : 298 | Loss : 0.008123267441987991
# Epoch : 299 | Loss : 0.008006518706679344
# Epoch : 300 | Loss : 0.007891399785876274
# Epoch : 301 | Loss : 0.00777801126241684
# Epoch : 302 | Loss : 0.007666223216801882
# Epoch : 303 | Loss : 0.007556022144854069
# Epoch : 304 | Loss : 0.007447452284395695
# Epoch : 305 | Loss : 0.007340414449572563
# Epoch : 306 | Loss : 0.007234929129481316
# Epoch : 307 | Loss : 0.007130932994186878
# Epoch : 308 | Loss : 0.007028459571301937
# Epoch : 309 | Loss : 0.006927454844117165
# Epoch : 310 | Loss : 0.006827887147665024
# Epoch : 311 | Loss : 0.006729797925800085
# Epoch : 312 | Loss : 0.006633058190345764
# Epoch : 313 | Loss : 0.0065377093851566315
# Epoch : 314 | Loss : 0.00644375616684556
# Epoch : 315 | Loss : 0.006351136136800051
# Epoch : 316 | Loss : 0.0062598902732133865
# Epoch : 317 | Loss : 0.006169907748699188
# Epoch : 318 | Loss : 0.006081216037273407
# Epoch : 319 | Loss : 0.0059938328340649605
# Epoch : 320 | Loss : 0.005907698068767786
# Epoch : 321 | Loss : 0.005822812672704458
# Epoch : 322 | Loss : 0.005739136133342981
# Epoch : 323 | Loss : 0.005656651221215725
# Epoch : 324 | Loss : 0.005575371440500021
# Epoch : 325 | Loss : 0.005495200864970684
# Epoch : 326 | Loss : 0.005416257306933403
# Epoch : 327 | Loss : 0.005338386166840792
# Epoch : 328 | Loss : 0.005261686164885759
# Epoch : 329 | Loss : 0.005186065100133419
# Epoch : 330 | Loss : 0.005111548118293285
# Epoch : 331 | Loss : 0.005038064904510975
# Epoch : 332 | Loss : 0.004965642932802439
# Epoch : 333 | Loss : 0.00489431107416749
# Epoch : 334 | Loss : 0.0048239510506391525
# Epoch : 335 | Loss : 0.004754645749926567
# Epoch : 336 | Loss : 0.004686315543949604
# Epoch : 337 | Loss : 0.004618946462869644
# Epoch : 338 | Loss : 0.004552602302283049
# Epoch : 339 | Loss : 0.004487159196287394
# Epoch : 340 | Loss : 0.00442266883328557
# Epoch : 341 | Loss : 0.0043590981513261795
# Epoch : 342 | Loss : 0.004296472296118736
# Epoch : 343 | Loss : 0.004234688822180033
# Epoch : 344 | Loss : 0.004173841327428818
# Epoch : 345 | Loss : 0.004113874398171902
# Epoch : 346 | Loss : 0.004054752178490162
# Epoch : 347 | Loss : 0.003996480256319046
# Epoch : 348 | Loss : 0.003939032554626465
# Epoch : 349 | Loss : 0.0038824346847832203
# Epoch : 350 | Loss : 0.0038266454357653856
# Epoch : 351 | Loss : 0.0037716422230005264
# Epoch : 352 | Loss : 0.003717448329553008
# Epoch : 353 | Loss : 0.0036640025209635496
# Epoch : 354 | Loss : 0.0036113555543124676
# Epoch : 355 | Loss : 0.003559419186785817
# Epoch : 356 | Loss : 0.0035082828253507614
# Epoch : 357 | Loss : 0.0034578684717416763
# Epoch : 358 | Loss : 0.003408175427466631
# Epoch : 359 | Loss : 0.00335919251665473
# Epoch : 360 | Loss : 0.0033109120558947325
# Epoch : 361 | Loss : 0.0032633263617753983
# Epoch : 362 | Loss : 0.0032164219301193953
# Epoch : 363 | Loss : 0.003170180832967162
# Epoch : 364 | Loss : 0.003124622395262122
# Epoch : 365 | Loss : 0.0030797389335930347
# Epoch : 366 | Loss : 0.003035481320694089
# Epoch : 367 | Loss : 0.0029918525833636522
# Epoch : 368 | Loss : 0.002948855049908161
# Epoch : 369 | Loss : 0.0029064605478197336
# Epoch : 370 | Loss : 0.0028646872378885746
# Epoch : 371 | Loss : 0.002823528368026018
# Epoch : 372 | Loss : 0.002782949712127447
# Epoch : 373 | Loss : 0.0027429386973381042
# Epoch : 374 | Loss : 0.002703555626794696
# Epoch : 375 | Loss : 0.0026646950282156467
# Epoch : 376 | Loss : 0.002626413246616721
# Epoch : 377 | Loss : 0.0025886278599500656
# Epoch : 378 | Loss : 0.002551424317061901
# Epoch : 379 | Loss : 0.0025147960986942053
# Epoch : 380 | Loss : 0.0024786328431218863
# Epoch : 381 | Loss : 0.002443001139909029
# Epoch : 382 | Loss : 0.0024078874848783016
# Epoch : 383 | Loss : 0.0023732827976346016
# Epoch : 384 | Loss : 0.0023391786962747574
# Epoch : 385 | Loss : 0.0023055728524923325
# Epoch : 386 | Loss : 0.002272437559440732
# Epoch : 387 | Loss : 0.002239767462015152
# Epoch : 388 | Loss : 0.0022075935266911983
# Epoch : 389 | Loss : 0.00217586406506598
# Epoch : 390 | Loss : 0.0021445821039378643
# Epoch : 391 | Loss : 0.0021137488074600697
# Epoch : 392 | Loss : 0.0020833988673985004
# Epoch : 393 | Loss : 0.0020534577779471874
# Epoch : 394 | Loss : 0.0020239297300577164
# Epoch : 395 | Loss : 0.0019948547706007957
# Epoch : 396 | Loss : 0.0019661779515445232
# Epoch : 397 | Loss : 0.0019379188306629658
# Epoch : 398 | Loss : 0.0019100549397990108
# Epoch : 399 | Loss : 0.0018826196901500225
# Epoch : 400 | Loss : 0.0018555732676759362
# Epoch : 401 | Loss : 0.0018288816791027784
# Epoch : 402 | Loss : 0.0018026132602244616
# Epoch : 403 | Loss : 0.0017767135286703706
# Epoch : 404 | Loss : 0.0017511618789285421
# Epoch : 405 | Loss : 0.0017259982414543629
# Epoch : 406 | Loss : 0.0017011964228004217
# Epoch : 407 | Loss : 0.001676752814091742
# Epoch : 408 | Loss : 0.0016526586841791868
# Epoch : 409 | Loss : 0.001628919504582882
# Epoch : 410 | Loss : 0.0016054873121902347
# Epoch : 411 | Loss : 0.0015824097208678722
# Epoch : 412 | Loss : 0.001559678465127945
# Epoch : 413 | Loss : 0.001537266536615789
# Epoch : 414 | Loss : 0.0015151799889281392
# Epoch : 415 | Loss : 0.0014934125356376171
# Epoch : 416 | Loss : 0.0014719476457685232
# Epoch : 417 | Loss : 0.0014507824089378119
# Epoch : 418 | Loss : 0.001429937081411481
# Epoch : 419 | Loss : 0.0014093628851696849
# Epoch : 420 | Loss : 0.0013891283888369799
# Epoch : 421 | Loss : 0.0013691479107365012
# Epoch : 422 | Loss : 0.001349478610791266
# Epoch : 423 | Loss : 0.0013300917344167829
# Epoch : 424 | Loss : 0.0013109861174598336
# Epoch : 425 | Loss : 0.0012921295128762722
# Epoch : 426 | Loss : 0.0012735628988593817
# Epoch : 427 | Loss : 0.0012552749831229448
# Epoch : 428 | Loss : 0.0012372175697237253
# Epoch : 429 | Loss : 0.001219449331983924
# Epoch : 430 | Loss : 0.0012019244022667408
# Epoch : 431 | Loss : 0.0011846343986690044
# Epoch : 432 | Loss : 0.0011676206486299634
# Epoch : 433 | Loss : 0.0011508285533636808
# Epoch : 434 | Loss : 0.0011342914076521993
# Epoch : 435 | Loss : 0.0011180021101608872
# Epoch : 436 | Loss : 0.001101936912164092
# Epoch : 437 | Loss : 0.001086098956875503
# Epoch : 438 | Loss : 0.001070491736754775
# Epoch : 439 | Loss : 0.0010551071027293801
# Epoch : 440 | Loss : 0.001039933180436492
# Epoch : 441 | Loss : 0.0010249826591461897
# Epoch : 442 | Loss : 0.0010102605447173119
# Epoch : 443 | Loss : 0.0009957440197467804
# Epoch : 444 | Loss : 0.0009814380900934339
# Epoch : 445 | Loss : 0.0009673369931988418
# Epoch : 446 | Loss : 0.0009534277487546206
# Epoch : 447 | Loss : 0.0009397243848070502
# Epoch : 448 | Loss : 0.0009262139210477471
# Epoch : 449 | Loss : 0.0009129068348556757
# Epoch : 450 | Loss : 0.0008997865952551365
# Epoch : 451 | Loss : 0.0008868531440384686
# Epoch : 452 | Loss : 0.0008741130004636943
# Epoch : 453 | Loss : 0.0008615555707365274
# Epoch : 454 | Loss : 0.0008491533226333559
# Epoch : 455 | Loss : 0.000836953695397824
# Epoch : 456 | Loss : 0.0008249174570664763
# Epoch : 457 | Loss : 0.0008130828500725329
# Epoch : 458 | Loss : 0.0008013929473236203
# Epoch : 459 | Loss : 0.0007898694602772593
# Epoch : 460 | Loss : 0.0007785169873386621
# Epoch : 461 | Loss : 0.0007673320942558348
# Epoch : 462 | Loss : 0.0007562984246760607
# Epoch : 463 | Loss : 0.0007454255828633904
# Epoch : 464 | Loss : 0.0007347198552452028
# Epoch : 465 | Loss : 0.0007241572020575404
# Epoch : 466 | Loss : 0.0007137532811611891
# Epoch : 467 | Loss : 0.0007034941809251904
# Epoch : 468 | Loss : 0.0006933904951438308
# Epoch : 469 | Loss : 0.000683416030369699
# Epoch : 470 | Loss : 0.0006735893548466265
# Epoch : 471 | Loss : 0.0006639192579314113
# Epoch : 472 | Loss : 0.0006543784984387457
# Epoch : 473 | Loss : 0.0006449643988162279
# Epoch : 474 | Loss : 0.0006357093807309866
# Epoch : 475 | Loss : 0.000626572233159095
# Epoch : 476 | Loss : 0.0006175676826387644
# Epoch : 477 | Loss : 0.000608691421803087
# Epoch : 478 | Loss : 0.0005999449058435857
# Epoch : 479 | Loss : 0.0005913111963309348
# Epoch : 480 | Loss : 0.0005828144494444132
# Epoch : 481 | Loss : 0.0005744530353695154
# Epoch : 482 | Loss : 0.0005661838804371655
# Epoch : 483 | Loss : 0.000558057043235749
# Epoch : 484 | Loss : 0.0005500257830135524
# Epoch : 485 | Loss : 0.0005421272944658995
# Epoch : 486 | Loss : 0.0005343368975445628
# Epoch : 487 | Loss : 0.000526661635376513
# Epoch : 488 | Loss : 0.0005190789233893156
# Epoch : 489 | Loss : 0.0005116328247822821
# Epoch : 490 | Loss : 0.000504270545206964
# Epoch : 491 | Loss : 0.0004970250884070992
# Epoch : 492 | Loss : 0.0004898822517134249
# Epoch : 493 | Loss : 0.0004828397068195045
# Epoch : 494 | Loss : 0.0004759051953442395
# Epoch : 495 | Loss : 0.0004690687055699527
# Epoch : 496 | Loss : 0.00046232668682932854
# Epoch : 497 | Loss : 0.00045567937195301056
# Epoch : 498 | Loss : 0.0004491369181778282
# Epoch : 499 | Loss : 0.00044267598423175514
# Prediction (after training) 4 7.975813865661621

# %%
# optimizer Adam
model = Model()

criterion = torch.nn.MSELoss(reduction = 'sum')
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# Training loop
for epoch in range(500):
    # 1) Forward pass
    y_pred = model(x_data)
    # 2) Compute and print loss
    loss = criterion(y_pred, y_data)
    print(f"Epoch : {epoch} | Loss : {loss.item()} ")
    
    # Zero gradients, perform a backward pass, and update the weights.
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    
    
# After training
hour_var = tensor([[4.0]])
y_pred = model(hour_var)
print("Prediction (after training)", 4, model(hour_var).data[0][0].item())
# Out:
# Epoch : 0 | Loss : 92.6151123046875
# Epoch : 1 | Loss : 91.58865356445312
# Epoch : 2 | Loss : 90.56816101074219
# Epoch : 3 | Loss : 89.5537338256836
# Epoch : 4 | Loss : 88.54544067382812
# Epoch : 5 | Loss : 87.54339599609375
# Epoch : 6 | Loss : 86.5477066040039
# Epoch : 7 | Loss : 85.55844116210938
# Epoch : 8 | Loss : 84.57569122314453
# Epoch : 9 | Loss : 83.59954833984375
# Epoch : 10 | Loss : 82.63009643554688
# Epoch : 11 | Loss : 81.66739654541016
# Epoch : 12 | Loss : 80.7115478515625
# Epoch : 13 | Loss : 79.7625961303711
# Epoch : 14 | Loss : 78.82061767578125
# Epoch : 15 | Loss : 77.88568115234375
# Epoch : 16 | Loss : 76.95783233642578
# Epoch : 17 | Loss : 76.03713989257812
# Epoch : 18 | Loss : 75.1236572265625
# Epoch : 19 | Loss : 74.2174072265625
# Epoch : 20 | Loss : 73.31845092773438
# Epoch : 21 | Loss : 72.42683410644531
# Epoch : 22 | Loss : 71.54257202148438
# Epoch : 23 | Loss : 70.66571044921875
# Epoch : 24 | Loss : 69.79627227783203
# Epoch : 25 | Loss : 68.93426513671875
# Epoch : 26 | Loss : 68.0797348022461
# Epoch : 27 | Loss : 67.2326889038086
# Epoch : 28 | Loss : 66.39312744140625
# Epoch : 29 | Loss : 65.56108093261719
# Epoch : 30 | Loss : 64.73652648925781
# Epoch : 31 | Loss : 63.91950988769531
# Epoch : 32 | Loss : 63.1099853515625
# Epoch : 33 | Loss : 62.3079833984375
# Epoch : 34 | Loss : 61.51347351074219
# Epoch : 35 | Loss : 60.726470947265625
# Epoch : 36 | Loss : 59.946937561035156
# Epoch : 37 | Loss : 59.174888610839844
# Epoch : 38 | Loss : 58.41029357910156
# Epoch : 39 | Loss : 57.65312957763672
# Epoch : 40 | Loss : 56.90339279174805
# Epoch : 41 | Loss : 56.161048889160156
# Epoch : 42 | Loss : 55.42607879638672
# Epoch : 43 | Loss : 54.698455810546875
# Epoch : 44 | Loss : 53.9781494140625
# Epoch : 45 | Loss : 53.26513671875
# Epoch : 46 | Loss : 52.55938720703125
# Epoch : 47 | Loss : 51.860877990722656
# Epoch : 48 | Loss : 51.16956329345703
# Epoch : 49 | Loss : 50.485408782958984
# Epoch : 50 | Loss : 49.808387756347656
# Epoch : 51 | Loss : 49.13846206665039
# Epoch : 52 | Loss : 48.47559356689453
# Epoch : 53 | Loss : 47.81975173950195
# Epoch : 54 | Loss : 47.17088317871094
# Epoch : 55 | Loss : 46.52897262573242
# Epoch : 56 | Loss : 45.89395523071289
# Epoch : 57 | Loss : 45.26580810546875
# Epoch : 58 | Loss : 44.64448547363281
# Epoch : 59 | Loss : 44.029937744140625
# Epoch : 60 | Loss : 43.4221305847168
# Epoch : 61 | Loss : 42.821022033691406
# Epoch : 62 | Loss : 42.2265739440918
# Epoch : 63 | Loss : 41.638729095458984
# Epoch : 64 | Loss : 41.057456970214844
# Epoch : 65 | Loss : 40.48271179199219
# Epoch : 66 | Loss : 39.91443634033203
# Epoch : 67 | Loss : 39.352603912353516
# Epoch : 68 | Loss : 38.797157287597656
# Epoch : 69 | Loss : 38.24806213378906
# Epoch : 70 | Loss : 37.70526885986328
# Epoch : 71 | Loss : 37.16872787475586
# Epoch : 72 | Loss : 36.63840103149414
# Epoch : 73 | Loss : 36.11424255371094
# Epoch : 74 | Loss : 35.59619903564453
# Epoch : 75 | Loss : 35.084228515625
# Epoch : 76 | Loss : 34.57828903198242
# Epoch : 77 | Loss : 34.07833480834961
# Epoch : 78 | Loss : 33.584312438964844
# Epoch : 79 | Loss : 33.096187591552734
# Epoch : 80 | Loss : 32.61389923095703
# Epoch : 81 | Loss : 32.137420654296875
# Epoch : 82 | Loss : 31.666690826416016
# Epoch : 83 | Loss : 31.201675415039062
# Epoch : 84 | Loss : 30.742313385009766
# Epoch : 85 | Loss : 30.2885684967041
# Epoch : 86 | Loss : 29.84040069580078
# Epoch : 87 | Loss : 29.39775276184082
# Epoch : 88 | Loss : 28.960590362548828
# Epoch : 89 | Loss : 28.528858184814453
# Epoch : 90 | Loss : 28.10251235961914
# Epoch : 91 | Loss : 27.681514739990234
# Epoch : 92 | Loss : 27.265804290771484
# Epoch : 93 | Loss : 26.855356216430664
# Epoch : 94 | Loss : 26.450111389160156
# Epoch : 95 | Loss : 26.050025939941406
# Epoch : 96 | Loss : 25.655059814453125
# Epoch : 97 | Loss : 25.265165328979492
# Epoch : 98 | Loss : 24.880292892456055
# Epoch : 99 | Loss : 24.500408172607422
# Epoch : 100 | Loss : 24.125459671020508
# Epoch : 101 | Loss : 23.755399703979492
# Epoch : 102 | Loss : 23.390186309814453
# Epoch : 103 | Loss : 23.02978515625
# Epoch : 104 | Loss : 22.67414093017578
# Epoch : 105 | Loss : 22.32320785522461
# Epoch : 106 | Loss : 21.97695541381836
# Epoch : 107 | Loss : 21.635324478149414
# Epoch : 108 | Loss : 21.29827880859375
# Epoch : 109 | Loss : 20.96577262878418
# Epoch : 110 | Loss : 20.637767791748047
# Epoch : 111 | Loss : 20.31421661376953
# Epoch : 112 | Loss : 19.995073318481445
# Epoch : 113 | Loss : 19.6803035736084
# Epoch : 114 | Loss : 19.369857788085938
# Epoch : 115 | Loss : 19.06369400024414
# Epoch : 116 | Loss : 18.761770248413086
# Epoch : 117 | Loss : 18.464046478271484
# Epoch : 118 | Loss : 18.17047691345215
# Epoch : 119 | Loss : 17.881023406982422
# Epoch : 120 | Loss : 17.595643997192383
# Epoch : 121 | Loss : 17.314292907714844
# Epoch : 122 | Loss : 17.03693389892578
# Epoch : 123 | Loss : 16.763521194458008
# Epoch : 124 | Loss : 16.494014739990234
# Epoch : 125 | Loss : 16.228378295898438
# Epoch : 126 | Loss : 15.96656608581543
# Epoch : 127 | Loss : 15.708541870117188
# Epoch : 128 | Loss : 15.45426082611084
# Epoch : 129 | Loss : 15.203685760498047
# Epoch : 130 | Loss : 14.956775665283203
# Epoch : 131 | Loss : 14.713489532470703
# Epoch : 132 | Loss : 14.473790168762207
# Epoch : 133 | Loss : 14.237641334533691
# Epoch : 134 | Loss : 14.004995346069336
# Epoch : 135 | Loss : 13.775819778442383
# Epoch : 136 | Loss : 13.55007266998291
# Epoch : 137 | Loss : 13.327719688415527
# Epoch : 138 | Loss : 13.108720779418945
# Epoch : 139 | Loss : 12.893033981323242
# Epoch : 140 | Loss : 12.680627822875977
# Epoch : 141 | Loss : 12.471460342407227
# Epoch : 142 | Loss : 12.265499114990234
# Epoch : 143 | Loss : 12.062701225280762
# Epoch : 144 | Loss : 11.863028526306152
# Epoch : 145 | Loss : 11.666450500488281
# Epoch : 146 | Loss : 11.47292709350586
# Epoch : 147 | Loss : 11.28242301940918
# Epoch : 148 | Loss : 11.094903945922852
# Epoch : 149 | Loss : 10.910331726074219
# Epoch : 150 | Loss : 10.728669166564941
# Epoch : 151 | Loss : 10.549884796142578
# Epoch : 152 | Loss : 10.373940467834473
# Epoch : 153 | Loss : 10.200801849365234
# Epoch : 154 | Loss : 10.030438423156738
# Epoch : 155 | Loss : 9.862810134887695
# Epoch : 156 | Loss : 9.697888374328613
# Epoch : 157 | Loss : 9.535633087158203
# Epoch : 158 | Loss : 9.376012802124023
# Epoch : 159 | Loss : 9.218998908996582
# Epoch : 160 | Loss : 9.064552307128906
# Epoch : 161 | Loss : 8.912641525268555
# Epoch : 162 | Loss : 8.763237953186035
# Epoch : 163 | Loss : 8.616303443908691
# Epoch : 164 | Loss : 8.471808433532715
# Epoch : 165 | Loss : 8.329719543457031
# Epoch : 166 | Loss : 8.190009117126465
# Epoch : 167 | Loss : 8.052640914916992
# Epoch : 168 | Loss : 7.917585849761963
# Epoch : 169 | Loss : 7.784813404083252
# Epoch : 170 | Loss : 7.654291152954102
# Epoch : 171 | Loss : 7.525992393493652
# Epoch : 172 | Loss : 7.399884223937988
# Epoch : 173 | Loss : 7.275935649871826
# Epoch : 174 | Loss : 7.154120922088623
# Epoch : 175 | Loss : 7.0344085693359375
# Epoch : 176 | Loss : 6.9167680740356445
# Epoch : 177 | Loss : 6.801171779632568
# Epoch : 178 | Loss : 6.687590599060059
# Epoch : 179 | Loss : 6.5759968757629395
# Epoch : 180 | Loss : 6.466362476348877
# Epoch : 181 | Loss : 6.358658313751221
# Epoch : 182 | Loss : 6.252859592437744
# Epoch : 183 | Loss : 6.148935794830322
# Epoch : 184 | Loss : 6.04686164855957
# Epoch : 185 | Loss : 5.946610927581787
# Epoch : 186 | Loss : 5.848154067993164
# Epoch : 187 | Loss : 5.751468658447266
# Epoch : 188 | Loss : 5.656527519226074
# Epoch : 189 | Loss : 5.563302993774414
# Epoch : 190 | Loss : 5.471770763397217
# Epoch : 191 | Loss : 5.381904602050781
# Epoch : 192 | Loss : 5.29368257522583
# Epoch : 193 | Loss : 5.2070770263671875
# Epoch : 194 | Loss : 5.122064113616943
# Epoch : 195 | Loss : 5.038620471954346
# Epoch : 196 | Loss : 4.95672082901001
# Epoch : 197 | Loss : 4.876342296600342
# Epoch : 198 | Loss : 4.79746150970459
# Epoch : 199 | Loss : 4.7200541496276855
# Epoch : 200 | Loss : 4.644099235534668
# Epoch : 201 | Loss : 4.569572448730469
# Epoch : 202 | Loss : 4.4964494705200195
# Epoch : 203 | Loss : 4.424713134765625
# Epoch : 204 | Loss : 4.354338645935059
# Epoch : 205 | Loss : 4.285301685333252
# Epoch : 206 | Loss : 4.21758508682251
# Epoch : 207 | Loss : 4.15116548538208
# Epoch : 208 | Loss : 4.08602237701416
# Epoch : 209 | Loss : 4.0221357345581055
# Epoch : 210 | Loss : 3.9594838619232178
# Epoch : 211 | Loss : 3.8980464935302734
# Epoch : 212 | Loss : 3.837803840637207
# Epoch : 213 | Loss : 3.7787392139434814
# Epoch : 214 | Loss : 3.720827579498291
# Epoch : 215 | Loss : 3.6640520095825195
# Epoch : 216 | Loss : 3.6083950996398926
# Epoch : 217 | Loss : 3.5538370609283447
# Epoch : 218 | Loss : 3.500356674194336
# Epoch : 219 | Loss : 3.4479405879974365
# Epoch : 220 | Loss : 3.396566867828369
# Epoch : 221 | Loss : 3.346219539642334
# Epoch : 222 | Loss : 3.296879768371582
# Epoch : 223 | Loss : 3.2485287189483643
# Epoch : 224 | Loss : 3.201152801513672
# Epoch : 225 | Loss : 3.1547322273254395
# Epoch : 226 | Loss : 3.1092522144317627
# Epoch : 227 | Loss : 3.0646958351135254
# Epoch : 228 | Loss : 3.0210447311401367
# Epoch : 229 | Loss : 2.9782843589782715
# Epoch : 230 | Loss : 2.936400890350342
# Epoch : 231 | Loss : 2.895374298095703
# Epoch : 232 | Loss : 2.855193853378296
# Epoch : 233 | Loss : 2.8158392906188965
# Epoch : 234 | Loss : 2.7773001194000244
# Epoch : 235 | Loss : 2.739557981491089
# Epoch : 236 | Loss : 2.702601671218872
# Epoch : 237 | Loss : 2.6664154529571533
# Epoch : 238 | Loss : 2.6309831142425537
# Epoch : 239 | Loss : 2.596294403076172
# Epoch : 240 | Loss : 2.56233286857605
# Epoch : 241 | Loss : 2.5290844440460205
# Epoch : 242 | Loss : 2.496540069580078
# Epoch : 243 | Loss : 2.4646811485290527
# Epoch : 244 | Loss : 2.433497905731201
# Epoch : 245 | Loss : 2.4029762744903564
# Epoch : 246 | Loss : 2.3731038570404053
# Epoch : 247 | Loss : 2.3438687324523926
# Epoch : 248 | Loss : 2.3152594566345215
# Epoch : 249 | Loss : 2.2872633934020996
# Epoch : 250 | Loss : 2.259866952896118
# Epoch : 251 | Loss : 2.233060836791992
# Epoch : 252 | Loss : 2.206831216812134
# Epoch : 253 | Loss : 2.1811697483062744
# Epoch : 254 | Loss : 2.156064510345459
# Epoch : 255 | Loss : 2.131502628326416
# Epoch : 256 | Loss : 2.1074752807617188
# Epoch : 257 | Loss : 2.083970069885254
# Epoch : 258 | Loss : 2.060978651046753
# Epoch : 259 | Loss : 2.0384891033172607
# Epoch : 260 | Loss : 2.016493558883667
# Epoch : 261 | Loss : 1.994978666305542
# Epoch : 262 | Loss : 1.9739375114440918
# Epoch : 263 | Loss : 1.953359842300415
# Epoch : 264 | Loss : 1.9332358837127686
# Epoch : 265 | Loss : 1.9135559797286987
# Epoch : 266 | Loss : 1.8943126201629639
# Epoch : 267 | Loss : 1.8754947185516357
# Epoch : 268 | Loss : 1.8570947647094727
# Epoch : 269 | Loss : 1.8391038179397583
# Epoch : 270 | Loss : 1.8215129375457764
# Epoch : 271 | Loss : 1.8043144941329956
# Epoch : 272 | Loss : 1.7874997854232788
# Epoch : 273 | Loss : 1.771061658859253
# Epoch : 274 | Loss : 1.7549903392791748
# Epoch : 275 | Loss : 1.7392805814743042
# Epoch : 276 | Loss : 1.7239218950271606
# Epoch : 277 | Loss : 1.7089080810546875
# Epoch : 278 | Loss : 1.6942322254180908
# Epoch : 279 | Loss : 1.679887056350708
# Epoch : 280 | Loss : 1.6658647060394287
# Epoch : 281 | Loss : 1.652158260345459
# Epoch : 282 | Loss : 1.6387627124786377
# Epoch : 283 | Loss : 1.6256681680679321
# Epoch : 284 | Loss : 1.612870693206787
# Epoch : 285 | Loss : 1.6003614664077759
# Epoch : 286 | Loss : 1.5881357192993164
# Epoch : 287 | Loss : 1.5761868953704834
# Epoch : 288 | Loss : 1.5645081996917725
# Epoch : 289 | Loss : 1.5530959367752075
# Epoch : 290 | Loss : 1.5419410467147827
# Epoch : 291 | Loss : 1.5310393571853638
# Epoch : 292 | Loss : 1.520385503768921
# Epoch : 293 | Loss : 1.5099726915359497
# Epoch : 294 | Loss : 1.4997971057891846
# Epoch : 295 | Loss : 1.4898511171340942
# Epoch : 296 | Loss : 1.4801316261291504
# Epoch : 297 | Loss : 1.4706332683563232
# Epoch : 298 | Loss : 1.461349368095398
# Epoch : 299 | Loss : 1.4522764682769775
# Epoch : 300 | Loss : 1.4434083700180054
# Epoch : 301 | Loss : 1.4347419738769531
# Epoch : 302 | Loss : 1.4262720346450806
# Epoch : 303 | Loss : 1.4179930686950684
# Epoch : 304 | Loss : 1.4099011421203613
# Epoch : 305 | Loss : 1.4019924402236938
# Epoch : 306 | Loss : 1.3942619562149048
# Epoch : 307 | Loss : 1.3867065906524658
# Epoch : 308 | Loss : 1.3793201446533203
# Epoch : 309 | Loss : 1.3721003532409668
# Epoch : 310 | Loss : 1.365042805671692
# Epoch : 311 | Loss : 1.35814368724823
# Epoch : 312 | Loss : 1.3514000177383423
# Epoch : 313 | Loss : 1.3448059558868408
# Epoch : 314 | Loss : 1.3383588790893555
# Epoch : 315 | Loss : 1.3320553302764893
# Epoch : 316 | Loss : 1.3258931636810303
# Epoch : 317 | Loss : 1.31986665725708
# Epoch : 318 | Loss : 1.313974142074585
# Epoch : 319 | Loss : 1.308211326599121
# Epoch : 320 | Loss : 1.3025753498077393
# Epoch : 321 | Loss : 1.297062873840332
# Epoch : 322 | Loss : 1.2916719913482666
# Epoch : 323 | Loss : 1.28639817237854
# Epoch : 324 | Loss : 1.2812391519546509
# Epoch : 325 | Loss : 1.2761921882629395
# Epoch : 326 | Loss : 1.2712550163269043
# Epoch : 327 | Loss : 1.266422986984253
# Epoch : 328 | Loss : 1.2616956233978271
# Epoch : 329 | Loss : 1.2570688724517822
# Epoch : 330 | Loss : 1.252540946006775
# Epoch : 331 | Loss : 1.2481088638305664
# Epoch : 332 | Loss : 1.2437702417373657
# Epoch : 333 | Loss : 1.2395234107971191
# Epoch : 334 | Loss : 1.2353652715682983
# Epoch : 335 | Loss : 1.2312934398651123
# Epoch : 336 | Loss : 1.2273061275482178
# Epoch : 337 | Loss : 1.2234013080596924
# Epoch : 338 | Loss : 1.2195758819580078
# Epoch : 339 | Loss : 1.2158293724060059
# Epoch : 340 | Loss : 1.212158203125
# Epoch : 341 | Loss : 1.2085609436035156
# Epoch : 342 | Loss : 1.2050354480743408
# Epoch : 343 | Loss : 1.2015810012817383
# Epoch : 344 | Loss : 1.1981940269470215
# Epoch : 345 | Loss : 1.1948740482330322
# Epoch : 346 | Loss : 1.191617488861084
# Epoch : 347 | Loss : 1.1884257793426514
# Epoch : 348 | Loss : 1.1852941513061523
# Epoch : 349 | Loss : 1.1822224855422974
# Epoch : 350 | Loss : 1.1792082786560059
# Epoch : 351 | Loss : 1.1762516498565674
# Epoch : 352 | Loss : 1.1733496189117432
# Epoch : 353 | Loss : 1.1705002784729004
# Epoch : 354 | Loss : 1.167703628540039
# Epoch : 355 | Loss : 1.1649580001831055
# Epoch : 356 | Loss : 1.1622610092163086
# Epoch : 357 | Loss : 1.1596121788024902
# Epoch : 358 | Loss : 1.1570098400115967
# Epoch : 359 | Loss : 1.1544526815414429
# Epoch : 360 | Loss : 1.151940107345581
# Epoch : 361 | Loss : 1.1494693756103516
# Epoch : 362 | Loss : 1.1470409631729126
# Epoch : 363 | Loss : 1.1446528434753418
# Epoch : 364 | Loss : 1.1423044204711914
# Epoch : 365 | Loss : 1.1399939060211182
# Epoch : 366 | Loss : 1.137719988822937
# Epoch : 367 | Loss : 1.1354823112487793
# Epoch : 368 | Loss : 1.1332805156707764
# Epoch : 369 | Loss : 1.131111979484558
# Epoch : 370 | Loss : 1.1289772987365723
# Epoch : 371 | Loss : 1.1268748044967651
# Epoch : 372 | Loss : 1.1248034238815308
# Epoch : 373 | Loss : 1.1227614879608154
# Epoch : 374 | Loss : 1.1207501888275146
# Epoch : 375 | Loss : 1.1187667846679688
# Epoch : 376 | Loss : 1.1168116331100464
# Epoch : 377 | Loss : 1.1148836612701416
# Epoch : 378 | Loss : 1.112982153892517
# Epoch : 379 | Loss : 1.1111056804656982
# Epoch : 380 | Loss : 1.1092532873153687
# Epoch : 381 | Loss : 1.1074252128601074
# Epoch : 382 | Loss : 1.105621337890625
# Epoch : 383 | Loss : 1.1038397550582886
# Epoch : 384 | Loss : 1.102079153060913
# Epoch : 385 | Loss : 1.100340485572815
# Epoch : 386 | Loss : 1.0986227989196777
# Epoch : 387 | Loss : 1.0969245433807373
# Epoch : 388 | Loss : 1.09524667263031
# Epoch : 389 | Loss : 1.0935866832733154
# Epoch : 390 | Loss : 1.0919455289840698
# Epoch : 391 | Loss : 1.0903217792510986
# Epoch : 392 | Loss : 1.0887151956558228
# Epoch : 393 | Loss : 1.087125539779663
# Epoch : 394 | Loss : 1.0855522155761719
# Epoch : 395 | Loss : 1.0839937925338745
# Epoch : 396 | Loss : 1.082451343536377
# Epoch : 397 | Loss : 1.080923080444336
# Epoch : 398 | Loss : 1.079409122467041
# Epoch : 399 | Loss : 1.0779099464416504
# Epoch : 400 | Loss : 1.0764234066009521
# Epoch : 401 | Loss : 1.074949860572815
# Epoch : 402 | Loss : 1.0734894275665283
# Epoch : 403 | Loss : 1.0720404386520386
# Epoch : 404 | Loss : 1.070603370666504
# Epoch : 405 | Loss : 1.0691782236099243
# Epoch : 406 | Loss : 1.0677638053894043
# Epoch : 407 | Loss : 1.0663602352142334
# Epoch : 408 | Loss : 1.064967155456543
# Epoch : 409 | Loss : 1.0635838508605957
# Epoch : 410 | Loss : 1.0622109174728394
# Epoch : 411 | Loss : 1.0608465671539307
# Epoch : 412 | Loss : 1.059491515159607
# Epoch : 413 | Loss : 1.0581457614898682
# Epoch : 414 | Loss : 1.0568079948425293
# Epoch : 415 | Loss : 1.0554791688919067
# Epoch : 416 | Loss : 1.0541579723358154
# Epoch : 417 | Loss : 1.0528442859649658
# Epoch : 418 | Loss : 1.051538348197937
# Epoch : 419 | Loss : 1.050240159034729
# Epoch : 420 | Loss : 1.0489484071731567
# Epoch : 421 | Loss : 1.0476630926132202
# Epoch : 422 | Loss : 1.0463850498199463
# Epoch : 423 | Loss : 1.04511296749115
# Epoch : 424 | Loss : 1.043846845626831
# Epoch : 425 | Loss : 1.0425872802734375
# Epoch : 426 | Loss : 1.0413331985473633
# Epoch : 427 | Loss : 1.0400840044021606
# Epoch : 428 | Loss : 1.0388407707214355
# Epoch : 429 | Loss : 1.0376026630401611
# Epoch : 430 | Loss : 1.0363696813583374
# Epoch : 431 | Loss : 1.035141110420227
# Epoch : 432 | Loss : 1.0339173078536987
# Epoch : 433 | Loss : 1.032698392868042
# Epoch : 434 | Loss : 1.0314832925796509
# Epoch : 435 | Loss : 1.030272126197815
# Epoch : 436 | Loss : 1.0290656089782715
# Epoch : 437 | Loss : 1.027862787246704
# Epoch : 438 | Loss : 1.0266637802124023
# Epoch : 439 | Loss : 1.0254685878753662
# Epoch : 440 | Loss : 1.0242769718170166
# Epoch : 441 | Loss : 1.0230883359909058
# Epoch : 442 | Loss : 1.0219030380249023
# Epoch : 443 | Loss : 1.0207210779190063
# Epoch : 444 | Loss : 1.0195422172546387
# Epoch : 445 | Loss : 1.0183659791946411
# Epoch : 446 | Loss : 1.0171923637390137
# Epoch : 447 | Loss : 1.0160218477249146
# Epoch : 448 | Loss : 1.0148541927337646
# Epoch : 449 | Loss : 1.0136884450912476
# Epoch : 450 | Loss : 1.0125255584716797
# Epoch : 451 | Loss : 1.0113650560379028
# Epoch : 452 | Loss : 1.0102063417434692
# Epoch : 453 | Loss : 1.0090501308441162
# Epoch : 454 | Loss : 1.007896065711975
# Epoch : 455 | Loss : 1.0067439079284668
# Epoch : 456 | Loss : 1.00559401512146
# Epoch : 457 | Loss : 1.004446029663086
# Epoch : 458 | Loss : 1.0032992362976074
# Epoch : 459 | Loss : 1.0021545886993408
# Epoch : 460 | Loss : 1.001011610031128
# Epoch : 461 | Loss : 0.9998699426651001
# Epoch : 462 | Loss : 0.9987302422523499
# Epoch : 463 | Loss : 0.997591495513916
# Epoch : 464 | Loss : 0.9964545965194702
# Epoch : 465 | Loss : 0.9953192472457886
# Epoch : 466 | Loss : 0.9941849708557129
# Epoch : 467 | Loss : 0.9930521249771118
# Epoch : 468 | Loss : 0.991920530796051
# Epoch : 469 | Loss : 0.9907900094985962
# Epoch : 470 | Loss : 0.9896606206893921
# Epoch : 471 | Loss : 0.9885316491127014
# Epoch : 472 | Loss : 0.9874042272567749
# Epoch : 473 | Loss : 0.9862781763076782
# Epoch : 474 | Loss : 0.9851524829864502
# Epoch : 475 | Loss : 0.9840279221534729
# Epoch : 476 | Loss : 0.9829044342041016
# Epoch : 477 | Loss : 0.9817819595336914
# Epoch : 478 | Loss : 0.9806599617004395
# Epoch : 479 | Loss : 0.9795386791229248
# Epoch : 480 | Loss : 0.9784184694290161
# Epoch : 481 | Loss : 0.9772986173629761
# Epoch : 482 | Loss : 0.976179838180542
# Epoch : 483 | Loss : 0.9750615954399109
# Epoch : 484 | Loss : 0.9739433526992798
# Epoch : 485 | Loss : 0.9728264808654785
# Epoch : 486 | Loss : 0.9717101454734802
# Epoch : 487 | Loss : 0.9705944657325745
# Epoch : 488 | Loss : 0.9694785475730896
# Epoch : 489 | Loss : 0.9683636426925659
# Epoch : 490 | Loss : 0.9672497510910034
# Epoch : 491 | Loss : 0.9661359786987305
# Epoch : 492 | Loss : 0.9650225043296814
# Epoch : 493 | Loss : 0.9639092087745667
# Epoch : 494 | Loss : 0.9627963900566101
# Epoch : 495 | Loss : 0.9616844058036804
# Epoch : 496 | Loss : 0.9605729579925537
# Epoch : 497 | Loss : 0.9594612717628479
# Epoch : 498 | Loss : 0.9583505392074585
# Epoch : 499 | Loss : 0.9572391510009766
# Prediction (after training) 4 6.792271614074707
